# %%
import matplotlib.pyplot as plt
img = plt.imread('imge.png') # read image
plt.imshow(img) # show image

# %%
x=img[50:300,10:228,:] # cut a specific part of the image
plt.imshow(x) # show cut part

# %%
x
# Out:
# array([[[0.40392157, 0.45882353, 0.19607843, 1.        ],
#         [0.40392157, 0.45882353, 0.19607843, 1.        ],
#         [0.40784314, 0.4627451 , 0.2       , 1.        ],
#         ...,
#         [0.8862745 , 0.73333335, 0.6627451 , 1.        ],
#         [0.87058824, 0.7254902 , 0.6392157 , 1.        ],
#         [0.85490197, 0.7137255 , 0.61960787, 1.        ]],
#
#        [[0.40784314, 0.4627451 , 0.19607843, 1.        ],
#         [0.4117647 , 0.46666667, 0.2       , 1.        ],
#         [0.41568628, 0.47058824, 0.20392157, 1.        ],
#         ...,
#         [0.8745098 , 0.72156864, 0.6392157 , 1.        ],
#         [0.8666667 , 0.7176471 , 0.62352943, 1.        ],
#         [0.85882354, 0.7176471 , 0.6117647 , 1.        ]],
#
#        [[0.4117647 , 0.46666667, 0.2       , 1.        ],
#         [0.41568628, 0.47058824, 0.20392157, 1.        ],
#         [0.41960785, 0.4745098 , 0.20784314, 1.        ],
#         ...,
# ...
